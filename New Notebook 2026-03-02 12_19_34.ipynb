# %%
# %sh
cd /Workspace/procurement_bundle
touch src/**init**.py
touch src/procurement/**init**.py
touch src/procurement/lib/**init**.py
touch src/procurement/metadata/**init**.py
touch src/procurement/pipelines/**init**.py
touch src/procurement/pipelines/bronze/**init**.py
touch src/procurement/pipelines/silver/**init**.py
ls -la src/
ls -la src/procurement/
